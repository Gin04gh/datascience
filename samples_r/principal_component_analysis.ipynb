# %%
data_x <- iris[,1:4]
head(data_x)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1 5.1          3.5         1.4          0.2
# 2 4.9          3.0         1.4          0.2
# 3 4.7          3.2         1.3          0.2
# 4 4.6          3.1         1.5          0.2
# 5 5.0          3.6         1.4          0.2
# 6 5.4          3.9         1.7          0.4

# %%
pc <- princomp(data_x) # 主成分分析
summary(pc)
# Out:
# Importance of components:
#                           Comp.1     Comp.2     Comp.3      Comp.4
# Standard deviation     2.0494032 0.49097143 0.27872586 0.153870700
# Proportion of Variance 0.9246187 0.05306648 0.01710261 0.005212184
# Cumulative Proportion  0.9246187 0.97768521 0.99478782 1.000000000

# %%
# クラスプロット

label <- as.factor(iris[,5]) # (setosa, ..., versicolor, ..., virginica, ...)
plot(pc$scores[,1], pc$scores[,2], col=label) # 第1主成分得点と第2主成分得点でプロット
# Out:
# plot without title

# %%
sessionInfo()
# Out:
# R version 3.4.1 (2017-06-30)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04 LTS
#
# Matrix products: default
# BLAS: /opt/conda/lib/R/lib/libRblas.so
# LAPACK: /opt/conda/lib/R/lib/libRlapack.so
#
# locale:
# [1] en_US.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# loaded via a namespace (and not attached):
#  [1] compiler_3.4.1  magrittr_1.5    IRdisplay_0.4.4 pbdZMQ_0.3-2
#  [5] tools_3.4.1     htmltools_0.3.6 base64enc_0.1-3 crayon_1.3.4
#  [9] Rcpp_0.12.17    uuid_0.1-2      stringi_1.2.3   IRkernel_0.8.12
# [13] jsonlite_1.5    stringr_1.3.1   digest_0.6.15   repr_0.15.0
# [17] evaluate_0.10.1
