# %% [markdown]
# * https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pylab as plt
from sklearn import linear_model
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv("./data/train.csv")
df_test = pd.read_csv("./data/test.csv")
display(df_train.head())
display(df_test.head())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour    ...     PoolQC Fence MiscFeature MiscVal MoSold YrSold SaleType SaleCondition  SalePrice
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg         Lvl    ...        NaN   NaN         NaN       0      2   2008       WD        Normal     208500
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg         Lvl    ...        NaN   NaN         NaN       0      5   2007       WD        Normal     181500
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1         Lvl    ...        NaN   NaN         NaN       0      9   2008       WD        Normal     223500
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1         Lvl    ...        NaN   NaN         NaN       0      2   2006       WD       Abnorml     140000
# ...

# %%
display(df_train.describe())
display(df_test.describe())
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond      ...        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000      ...        1460.000000  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315     5.575342      ...          15.060959     2.758904     43.489041     6.321918  2007.815753  180921.195890
# std     421.610009    42.300571    24.284752    9981.264932     1.382997     1.112799      ...          55.757415    40.177307    496.123024     2.703626     1.328095   79442.502883
# min       1.000000    20.000000    21.000000    1300.000000     1.000000     1.000000      ...           0.000000     0.000000      0.000000     1.000000  2006.000000   34900.000000
# ...

# %%
# データの型の確認

print(df_train.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
# 欠損値の確認

print(df_train.isnull().sum())
print('-'*100)
print(df_test.isnull().sum())
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
# 欠損していないラベルデータをダミー変数化、欠損しているところは欠損ダミー変数化して予測

# ダミー化用に一度連結する
df_train_tmp = df_train.copy()
df_test_tmp = df_test.copy()
df_train_tmp = df_train_tmp.drop('SalePrice', axis=1)
df = pd.concat([df_train_tmp, df_test_tmp])
print('total row num: {}'.format(len(df)))

# 欠損していないラベルデータをダミー変数化、欠損しているところは欠損ダミー変数化
df = pd.get_dummies(df, dummy_na=True)
df = df.dropna(axis=1)
print('column num: {}\tna columns num: {}'.format(len(df.columns), sum(df.isnull().sum()>0)))

# x, y
df = pd.merge(train[['Id', 'SalePrice']], df, how='inner', on='Id')
train_y = df[['SalePrice']]
train_x = df.drop(['Id', 'SalePrice'], axis=1)
train_x.shape, train_y.shape
# Out:
# total row num: 2919
# column num: 321	na columns num: 0
# ((1460, 320), (1460, 1))

# %%
# いくつかの回帰手法の自由度決定済み係数を比較する

# 重回帰
lr = linear_model.LinearRegression()
lr.fit(train_x, train_y)
print('LinearRegression:\t{}'.format(lr.score(train_x, train_y)))

# リッジ回帰
ridge = linear_model.Ridge()
ridge.fit(train_x, train_y)
print('Ridge:\t{}'.format(ridge.score(train_x, train_y)))

# Lasso回帰
lasso = linear_model.Lasso()
lasso.fit(train_x, train_y)
print('Lasso:\t{}'.format(lasso.score(train_x, train_y)))

# ElasticNet
elasticnet = linear_model.ElasticNet()
elasticnet.fit(train_x, train_y)
print('ElasticNet:\t{}'.format(elasticnet.score(train_x, train_y)))
# Out:
# LinearRegression:	0.9261010002417056
# Ridge:	0.9171756307343478
# Lasso:	0.926063946218729
# ElasticNet:	0.8193936670940898

# %%
# 価格の分布、歪度を確認する

df_train['SalePrice'].hist(bins=100, figsize=(10,5))
plt.grid('off')
plt.show()
stats.skew(df_train['SalePrice'])
# Out:
# 1.880940746034036

# %% [markdown]
# * 歪度が高い（裾が右に長い分布）

# %%
# 対数価格の分布

plt.figure(figsize=(10,5))
plt.hist(np.log1p(df_train['SalePrice']), bins=100)
plt.show()

# %%
# ダミー変数化および対数価格で予測する

# ダミー化用に一度連結する
df_train_tmp = df_train.copy()
df_test_tmp = df_test.copy()
df_train_tmp = df_train_tmp.drop('SalePrice', axis=1)
df = pd.concat([df_train_tmp, df_test_tmp])
print('total row num: {}'.format(len(df)))

# 欠損していないラベルデータをダミー変数化、欠損しているところは欠損ダミー変数化
df = pd.get_dummies(df, dummy_na=True)
df = df.dropna(axis=1)
print('column num: {}\tna columns num: {}'.format(len(df.columns), sum(df.isnull().sum()>0)))

# x, y
df = pd.merge(train[['Id', 'SalePrice']], df, how='inner', on='Id')
train_y = np.log1p(df['SalePrice'])
train_x = df.drop(['Id', 'SalePrice'], axis=1)
train_x.shape, train_y.shape
# Out:
# total row num: 2919
# column num: 321	na columns num: 0
# ((1460, 320), (1460,))

# %%
# いくつかの回帰手法の自由度決定済み係数を比較する

# 重回帰
lr = linear_model.LinearRegression()
lr.fit(train_x, train_y)
print('LinearRegression:\t{}'.format(lr.score(train_x, train_y)))

# リッジ回帰
ridge = linear_model.Ridge()
ridge.fit(train_x, train_y)
print('Ridge:\t{}'.format(ridge.score(train_x, train_y)))

# Lasso回帰
lasso = linear_model.Lasso()
lasso.fit(train_x, train_y)
print('Lasso:\t{}'.format(lasso.score(train_x, train_y)))

# ElasticNet
elasticnet = linear_model.ElasticNet()
elasticnet.fit(train_x, train_y)
print('ElasticNet:\t{}'.format(elasticnet.score(train_x, train_y)))
# Out:
# LinearRegression:	0.9382780796248207
# Ridge:	0.9322394774761906
# Lasso:	0.7421954880645002
# ElasticNet:	0.761756094281343

# %%
# 説明変数に歪度が高いものも対数変換する

# ダミー化用に一度連結する
df_train_tmp = df_train.copy()
df_test_tmp = df_test.copy()
df_train_tmp = df_train_tmp.drop('SalePrice', axis=1)
df = pd.concat([df_train_tmp, df_test_tmp])
print('total row num: {}'.format(len(df)))

# 欠損していないラベルデータをダミー変数化、欠損しているところは欠損ダミー変数化
df = pd.get_dummies(df, dummy_na=True)
df = df.dropna(axis=1)
print('column num: {}\tna columns num: {}'.format(len(df.columns), sum(df.isnull().sum()>0)))

# 対数変換
df_tmp = df.drop('Id', axis=1)
target_cols = df.columns[df.dtypes != 'object'] # Id以外の数値カラム
skews = stats.skew(df[target_cols]) # 歪度を求める
target_cols = target_cols[skews > 0.75] # 歪度が高い（裾が右に長い分布）のカラム

log_cols = target_cols+'_log'
for log_col, target_col in zip(log_cols, target_cols):
    df[log_col] = np.log1p(df[target_col])
df = df.drop(target_cols, axis=1)
print('column num: {}'.format(len(df.columns)))

# x, y
df = pd.merge(train[['Id', 'SalePrice']], df, how='inner', on='Id')
train_y = np.log1p(df['SalePrice'])
train_x = df.drop(['Id', 'SalePrice'], axis=1)
train_x.shape, train_y.shape
# Out:
# total row num: 2919
# column num: 321	na columns num: 0
# column num: 321
# ((1460, 320), (1460,))

# %%
# いくつかの回帰手法の自由度決定済み係数を比較する

# 重回帰
lr = linear_model.LinearRegression()
lr.fit(train_x, train_y)
print('LinearRegression:\t{}'.format(lr.score(train_x, train_y)))

# リッジ回帰
ridge = linear_model.Ridge()
ridge.fit(train_x, train_y)
print('Ridge:\t{}'.format(ridge.score(train_x, train_y)))

# Lasso回帰
lasso = linear_model.Lasso()
lasso.fit(train_x, train_y)
print('Lasso:\t{}'.format(lasso.score(train_x, train_y)))

# ElasticNet
elasticnet = linear_model.ElasticNet()
elasticnet.fit(train_x, train_y)
print('ElasticNet:\t{}'.format(elasticnet.score(train_x, train_y)))
# Out:
# LinearRegression:	0.9422877350579
# Ridge:	0.9354585335272629
# Lasso:	0.40233814980587934
# ElasticNet:	0.4134809153538225

# %%
# 残差プロット

preds = lr.predict(train_x) # 教師データによる予測
plt.figure(figsize=(10,5))
plt.plot(preds, preds-train_y, 'o')
plt.hlines(y=0, xmin=min(preds), xmax=max(preds), color='darkgray')
plt.show()

# %% [markdown]
# * 特徴量変換を行わないまま予測させると、LassoやElasticNetは精度が良い
# * 特徴量変換を加えていくことで、重回帰分析の精度が上がっている
