# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pylab as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# !ls data
# Out:
# a-large-tennis-dataset-for-atp-and-itf-betting.zip  betting_moneyline.csv
# all_matches.csv					    betting_spreads.csv
# all_players.csv					    betting_totals.csv
# all_tournaments.csv				    countries.csv

# %%
reader = pd.read_csv('./data/all_matches.csv', chunksize=100)

# %%
reader.get_chunk(5)
# Out:
#    start_date    end_date  location court_surface  prize_money currency  year                      player_id   player_name                  opponent_id    ...    total_points  duration player_victory  retirement  seed  won_first_set  doubles  masters  round_num    nation
# 0  2012-06-11  2012-06-17  Slovakia          Clay        30000        €  2012                   adrian-partl      A. Partl                andrej-martin    ...            88.0  01:02:00              f           f   NaN              f        f      100          1  Slovakia
# 1  2012-06-11  2012-06-17  Slovakia          Clay        30000        €  2012                   adrian-partl      A. Partl                jozef-kovalik    ...           195.0  02:43:00              t           f   NaN              t        f      100          0  Slovakia
# ...

# %%
def preprocess(df):
    
    df = df.dropna()
    df = df[df['doubles'] == 'f']
    df = df[df['year'] >= 2017]
    df = df.drop(['start_date', 'end_date', 'location', 'prize_money', 'currency', 'player_id', 'opponent_id', 'duration', 'seed', 'nation'], axis=1)
    return df

df_matches = pd.concat((preprocess(r) for r in reader), ignore_index=True)

# %%
len(df_matches)
# Out:
# 22745

# %%
df_matches[['player_name', 'opponent_name', 'year', 'tournament']].head(10)
# Out:
#      player_name        opponent_name  year            tournament
# 0         A. Day  R. Rodriguez - Pace  2018  vancouver_challenger
# 1  A. Sarkissian             A. Vukic  2018  vancouver_challenger
# 2  A. Sarkissian              B. Gojo  2018  vancouver_challenger
# 3        A. Ward       T. Kwiatkowski  2018  vancouver_challenger
# 4     B. Sigouin          V. Pospisil  2018  vancouver_challenger
# 5        B. Gojo            J. Kubler  2018  vancouver_challenger
# 6        B. Gojo              K. King  2018  vancouver_challenger
# 7      B. Schnur             Y. Maden  2018  vancouver_challenger
# 8     C. Eubanks            G. Muller  2018  vancouver_challenger
# 9       D. Evans          E. Escobedo  2018  vancouver_challenger

# %%
tmp = df_matches[
    ((df_matches['player_name'] == 'K. Nishikori') & (df_matches['opponent_name'] == 'D. Thiem')& (df_matches['year'] == 2018) & (df_matches['tournament'] == 'roland-garros'))
    | 
    ((df_matches['player_name'] == 'D. Thiem') & (df_matches['opponent_name'] == 'K. Nishikori')& (df_matches['year'] == 2018) & (df_matches['tournament'] == 'roland-garros'))
]
tmp
# Out:
#      court_surface  year   player_name opponent_name     tournament        round  num_sets  sets_won  games_won    ...      return_points_attempted  total_points_won  total_points  player_victory  retirement  won_first_set  doubles  masters  round_num
# 2209          Clay  2018      D. Thiem  K. Nishikori  roland-garros  Round of 16       4.0       3.0       23.0    ...                        102.0             112.0         197.0               t           f              t        f     2000          4
# 2288          Clay  2018  K. Nishikori      D. Thiem  roland-garros  Round of 16       4.0       1.0       13.0    ...                         95.0              85.0         197.0               f           f              f        f     2000          4
#
# [2 rows x 44 columns]

# %% [markdown]
# * num_sets # 全体セット数
# * sets_won # 獲得セット数
# * games_won # 獲得ゲーム数
# * games_against # 喪失ゲーム数
# * tiebrakes_won # 獲得タイブレーク数？
# * tiebrakes_total # 全体タイブレーク数？
# * serve_rating # ？
# * aces # エース数
# * double_faults # ダブルフォルト数
# * first_serve_made # ファーストサービスが入った数=first_serve_points_attempted
# * first_serve_attempted # ファーストサービスをおこなった数
# * first_serve_points_made # ファーストサービス成功時の獲得ポイント数
# * first_serve_points_attempted # ファーストサービス成功時の全体ポイント数=first_serve_made
# * second_serve_points_made # セカンドサービス成功時の獲得ポイント数
# * second_serve_points_attempted # セカンドサービス成功時の全体ポイント数
# * break_points_saved # 被ブレイクポイントを守備した数
# * break_points_against # 全体の被ブレイクポイント数
# * service_game_won # ？
# * return_rating # ？
# * first_serve_return_points_made # 相手ファーストサービス成功時（リターン）の獲得ポイント数
# * first_serve_return_points_attempted # 相手ファーストサービス成功時（リターン）の全体ポイント数
# * second_serve_return_points_made # 相手セカンドサービス成功時（リターン）の獲得ポイント数
# * second_serve_return_points_attempted # 相手セカンドサービス成功時（リターン）の全体ポイント数
# * break_points_made # ブレイクポイントを獲得した数
# * break_points_attempted # 全体のブレイクポイント数
# * return_games_played #
# * service_points_won # サービスポイントを獲得した数
# * service_points_attempted # 全体のサービスポイント数
# * return_points_won # リターンポイントを獲得した数=first_serve_return_points_made+second_serve_return_points_made
# * return_points_attempted # 全体のリターンポイント数=first_serve_return_points_attempted+second_serve_return_points_attempted
# * total_points_won # トータルポイント獲得数=service_points_won+return_points_won
# * total_points # プレイされた合計ポイント数=service_points_attempted+return_points_attempted
# * player_vistory # 勝敗 boolean
# * retirement # 棄権したかどうか？ boolean
# * won_first_set # ファーストセットを勝ったかどうか？ boolean
# * doubles # ダブルスかどうか
# * masters # トーナメントのATPポイント（例：2000=グランドスラム）
# * round_num # 何回戦か

# %%
df_tmp = df_matches[df_matches['player_name'] == 'K. Nishikori']

# 復帰前か復帰後かのフラグ
df_tmp.loc[df_tmp['year'] >= 2018, 'returned'] = True
df_tmp.loc[df_tmp['year'] < 2018, 'returned'] = False

# ダブルフォルト率
df_tmp.loc[:, 'double_faults_rate'] = df_tmp['double_faults']/(df_tmp['first_serve_points_attempted']+df_tmp['second_serve_points_attempted'])

# ファーストサービス成功率
#df_tmp.loc[:, 'first_serve_rate']

# ファーストサービス成功時のポイント率
#df_tmp.loc[:, 'first_serve_point_rate']

# セカンドサービス成功率
#df_tmp.loc[:, 'second_serve_rate']

# セカンドサービス成功時のポイント率
#df_tmp.loc[:, 'second_serve_point_rate']

# 相手ファーストサービス成功時のポイント率
#df_tmp.loc[:, 'first_serve_return_point_rate']

# 相手セカンドサービス成功時のポイント率
#df_tmp.loc[:, 'second_serve_return_point_rate']


df_tmp
# Out:
#       court_surface  year   player_name     opponent_name                   tournament           round  num_sets  sets_won  games_won         ...          total_points  player_victory  retirement  won_first_set  doubles  masters  round_num  returned  double_faults_rate
# 303            Clay  2017  K. Nishikori     A. Dolgopolov                 buenos-aires          Finals       2.0       0.0       10.0         ...                 153.0               f           f              f        f      250          7     False            0.012821
# 304            Clay  2017  K. Nishikori        C. Berlocq                 buenos-aires     Semi-Finals       3.0       2.0       16.0         ...                 198.0               t           f              f        f      250          6     False            0.032609
# ...

# %%
df_prev = df_matches[((df_matches['player_name'] == 'K. Nishikori') &  (df_matches['year'] <= 2017))]
len(df_prev)
# Out:
# 43

# %%
df_prev.mean()
# Out:
# year                                    2017.000000
# num_sets                                   2.837209
# sets_won                                   1.790698
# games_won                                 14.837209
# games_against                             12.372093
# tiebreaks_won                              0.209302
# tiebreaks_total                            0.441860
# serve_rating                             269.930233
# aces                                       3.255814
# double_faults                              2.348837
# first_serve_made                          53.093023
# first_serve_attempted                     85.441860
# first_serve_points_made                   37.930233
# first_serve_points_attempted              53.093023
# second_serve_points_made                  16.860465
# second_serve_points_attempted             32.348837
# break_points_saved                         4.511628
# break_points_against                       7.093023
# ...

# %%
df_returned = df_matches[((df_matches['player_name'] == 'K. Nishikori') &  (df_matches['year'] == 2018))]
len(df_returned)
# Out:
# 27
